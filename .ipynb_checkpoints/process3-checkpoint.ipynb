# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1552\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df.drop(df.columns[5], axis=1,inplace=True)
df.columns
# Out:
# Index(['Opening', 'Opening.1', 'Title', 'Production company', 'Cast and crew',
#        'Ref.'],
#       dtype='object')

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 267       Columbia Pictures / Gary Sanchez Productions
# 268          Annapurna Pictures / Plan B Entertainment
# 269                                     Focus Features
# 270                                 Annapurna Pictures
# 271                                            Netflix
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Leigh Whannell (scree...    NaN
# 1    Lauren Wolkstein (director); Christopher Radcl...    NaN
# 2    Simon West (director); Duncan Falconer, Warren...    NaN
# 3    Warwick Thornton (director); David Tranter, St...    NaN
# 4    Jaume Collet-Serra (director); Byron Willinger...    NaN
# ..                                                 ...    ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...  [164]
# 268  Adam McKay (director/screenplay); Christian Ba...  [137]
# 269  Mimi Leder (director); Daniel Stiepleman (scre...  [228]
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...  [260]
# 271  David Slade (director); Charlie Brooker (scree...  [261]
#
# [272 rows x 6 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'd0ee04e516fc923e0faa3878404593b6'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/550?api_key=d0ee04e516fc923e0faa3878404593b6'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 267       Columbia Pictures / Gary Sanchez Productions
# 268          Annapurna Pictures / Plan B Entertainment
# 269                                     Focus Features
# 270                                 Annapurna Pictures
# 271                                            Netflix
#
#                                          Cast and crew   Ref. genres
# 0    Adam Robitel (director); Leigh Whannell (scree...    NaN  Drama
# 1    Lauren Wolkstein (director); Christopher Radcl...    NaN  Drama
# 2    Simon West (director); Duncan Falconer, Warren...    NaN  Drama
# 3    Warwick Thornton (director); David Tranter, St...    NaN  Drama
# 4    Jaume Collet-Serra (director); Byron Willinger...    NaN  Drama
# ..                                                 ...    ...    ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...  [164]  Drama
# 268  Adam McKay (director/screenplay); Christian Ba...  [137]  Drama
# 269  Mimi Leder (director); Daniel Stiepleman (scre...  [228]  Drama
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...  [260]  Drama
# 271  David Slade (director); Charlie Brooker (scree...  [261]  Drama
#
# [272 rows x 7 columns]

# %%
# df.to_csv('movies_2018.csv', index = False)

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew genres
# 0    Adam Robitel (director); Leigh Whannell (scree...  Drama
# 1    Lauren Wolkstein (director); Christopher Radcl...  Drama
# 2    Simon West (director); Duncan Falconer, Warren...  Drama
# 3    Warwick Thornton (director); David Tranter, St...  Drama
# 4    Jaume Collet-Serra (director); Byron Willinger...  Drama
# ..                                                 ...    ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...  Drama
# 268  Adam McKay (director/screenplay); Christian Ba...  Drama
# 269  Mimi Leder (director); Daniel Stiepleman (scre...  Drama
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...  Drama
# 271  David Slade (director); Charlie Brooker (scree...  Drama
#
# [272 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1552\930721595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1552\2274966287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1552\3672495884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew genres  \
# 0    Adam Robitel (director); Leigh Whannell (scree...  Drama
# 1    Lauren Wolkstein (director); Christopher Radcl...  Drama
# 2    Simon West (director); Duncan Falconer, Warren...  Drama
# 3    Warwick Thornton (director); David Tranter, St...  Drama
# 4    Jaume Collet-Serra (director); Byron Willinger...  Drama
# ..                                                 ...    ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...  Drama
# 268  Adam McKay (director/screenplay); Christian Ba...  Drama
# 269  Mimi Leder (director); Daniel Stiepleman (scre...  Drama
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...  Drama
# 271  David Slade (director); Charlie Brooker (scree...  Drama
#
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name
# 0    Leigh Whannell
# 1     Emily Althaus
# 2        Gemma Chan
# 3               NaN
# 4    Patrick Wilson
# ..              ...
# 267    Rebecca Hall
# 268    Steve Carell
# 269  Justin Theroux
# 270    Toby Kebbell
# 271   Asim Chaudhry
#
# [272 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name genres                 movie_title
# 0    Leigh Whannell  Drama     Insidious: The Last Key
# 1     Emily Althaus  Drama            The Strange Ones
# 2        Gemma Chan  Drama                    Stratton
# 3               NaN  Drama               Sweet Country
# 4    Patrick Wilson  Drama                The Commuter
# ..              ...    ...                         ...
# 267    Rebecca Hall  Drama             Holmes & Watson
# 268    Steve Carell  Drama                        Vice
# 269  Justin Theroux  Drama         On the Basis of Sex
# 270    Toby Kebbell  Drama                   Destroyer
# 271   Asim Chaudhry  Drama  Black Mirror: Bandersnatch
#
# [272 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18.to_csv('new_df18.csv', index=False)

# %% [markdown]
# Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1552\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1              Title  \
# 0     JANUARY          4        Escape Room
# 1     JANUARY          4         Rust Creek
# 2     JANUARY          4   American Hangman
# 3     JANUARY         11   A Dog's Way Home
# 4     JANUARY         11         The Upside
# ..        ...        ...                ...
# 237  DECEMBER         25  Spies in Disguise
# 238  DECEMBER         25       Little Women
# 239  DECEMBER         25               1917
# 240  DECEMBER         25         Just Mercy
# 241  DECEMBER         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 237  20th Century Fox / Blue Sky Studios / Chernin ...
# 238            Columbia Pictures / Regency Enterprises
# 239           Universal Pictures / DreamWorks Pictures
# 240          Warner Bros. Pictures / Participant Media
# 241                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 237  Nick Bruno, Troy Quane (directors); Brad Copel...  [132]
# 238  Greta Gerwig (director/screenplay); Saoirse Ro...  [221]
# 239  Sam Mendes (director/screenplay); Krysty Wilso...  [222]
# 240  Destin Daniel Cretton (director/screenplay), A...  [223]
# 241  Chinonye Chukwu (director/screenplay); Alfre W...  [224]
#
# [242 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 237  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 238       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 239               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 240         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 241           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#     genres
# 0    Drama
# 1    Drama
# 2    Drama
# 3    Drama
# 4    Drama
# ..     ...
# 237  Drama
# 238  Drama
# 239  Drama
# 240  Drama
# 241  Drama
#
# [242 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1552\203239715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1552\1562076556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1552\3736213850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')
new_df19['movie_title'] = new_df19['movie_title'].str.lower()
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 237  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 238            Greta Gerwig        Saoirse Ronan           Emma Watson
# 239              Sam Mendes        George MacKay  Dean-Charles Chapman
# 240   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 241         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name genres        movie_title  \
# 0    Deborah Ann Woll  Drama        escape room
# 1        Sean O'Bryan  Drama         rust creek
# 2       Oliver Dennis  Drama   american hangman
# 3     Alexandra Shipp  Drama   a dog's way home
# 4       Nicole Kidman  Drama         the upside
# ..                ...    ...                ...
# 237     Rashida Jones  Drama  spies in disguise
# 238     Florence Pugh  Drama       little women
# 239       Mark Strong  Drama               1917
# 240       Brie Larson  Drama         just mercy
# 241       Aldis Hodge  Drama           clemency
#
#                                                   comb
# 0    Taylor Russell Logan Miller Deborah Ann Woll A...
# 1    Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2    Donald Sutherland Vincent Kartheiser Oliver De...
# 3    Bryce Dallas Howard Edward James Olmos Alexand...
# 4    Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                                                 ...
# 237  Will Smith Tom Holland Rashida Jones Nick Brun...
# 238  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 239  George MacKay Dean-Charles Chapman Mark Strong...
# 240  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 241  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [242 rows x 7 columns]

# %%
my_df = new_df18.append(new_df19,ignore_index=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1552\3175913732.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   my_df = new_df18.append(new_df19,ignore_index=True)

# %%
my_df
# Out:
#               director_name       actor_1_name            actor_2_name  \
# 0              Adam Robitel          Lin Shaye           Angus Sampson
# 1          Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2                Simon West     Dominic Cooper          Austin Stowell
# 3          Warwick Thornton        Bryan Brown               Sam Neill
# 4        Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                      ...                ...                     ...
# 509  Nick Bruno, Troy Quane         Will Smith             Tom Holland
# 510            Greta Gerwig      Saoirse Ronan             Emma Watson
# 511              Sam Mendes      George MacKay    Dean-Charles Chapman
# 512   Destin Daniel Cretton  Michael B. Jordan              Jamie Foxx
# 513         Chinonye Chukwu      Alfre Woodard          Wendell Pierce
#
#        actor_3_name genres              movie_title  \
# 0    Leigh Whannell  Drama  insidious: the last key
# 1     Emily Althaus  Drama         the strange ones
# 2        Gemma Chan  Drama                 stratton
# 3           unknown  Drama            sweet country
# 4    Patrick Wilson  Drama             the commuter
# ..              ...    ...                      ...
# 509   Rashida Jones  Drama        spies in disguise
# 510   Florence Pugh  Drama             little women
# 511     Mark Strong  Drama                     1917
# 512     Brie Larson  Drama               just mercy
# 513     Aldis Hodge  Drama                 clemency
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 509  Will Smith Tom Holland Rashida Jones Nick Brun...
# 510  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 511  George MacKay Dean-Charles Chapman Mark Strong...
# 512  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 513  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [514 rows x 7 columns]

# %%
old_df = pd.read_csv('new_data.csv')

# %%
final_df = old_df.append(my_df,ignore_index=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1552\2046453413.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5873  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5874            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5875              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5876   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5877         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5873         Rashida Jones                            Drama
# 5874         Florence Pugh                            Drama
# 5875           Mark Strong                            Drama
# 5876           Brie Larson                            Drama
# 5877           Aldis Hodge                            Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5873                                  spies in disguise
# 5874                                       little women
# 5875                                               1917
# 5876                                         just mercy
# 5877                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5873  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5874  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5875  George MacKay Dean-Charles Chapman Mark Strong...
# 5876  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5877  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5878 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
final_df.to_csv('final_data.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [52], in <cell line: 2>()
#       1 final_df.isna().sum()
# ----> 2 final_df.to_csv('../datasets/final_data.csv',index=False)
#
# File E:\Anaconda\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File E:\Anaconda\lib\site-packages\pandas\io\formats\format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File E:\Anaconda\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File E:\Anaconda\lib\site-packages\pandas\io\common.py:697, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     695 # Only for write methods
#     696 if "r" not in mode and is_path:
# --> 697     check_parent_directory(str(handle))
#     699 if compression:
#     700     if compression != "zstd":
#     701         # compression libraries do not like an explicit text-mode
#
# File E:\Anaconda\lib\site-packages\pandas\io\common.py:571, in check_parent_directory(path)
#     569 parent = Path(path).parent
#     570 if not parent.is_dir():
# --> 571     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '..\datasets'
