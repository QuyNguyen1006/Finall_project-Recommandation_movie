# %% [markdown]
# xtracting features of 2020-2021-2022 movies from Wikipedia

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15296\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df.drop(df.columns[5], axis=1,inplace=True)
df
# Out:
#       Opening  Opening.1                              Title  \
# 0     JANUARY        7.0                            The 355
# 1     JANUARY        7.0           The Legend of La Llorona
# 2     JANUARY        7.0                       The Commando
# 3     JANUARY       14.0                             Scream
# 4     JANUARY       14.0  Hotel Transylvania: Transformania
# ..        ...        ...                                ...
# 190  DECEMBER       21.0       Puss in Boots: The Last Wish
# 191  DECEMBER       21.0        I Wanna Dance with Somebody
# 192  DECEMBER       25.0                            Babylon
# 193  DECEMBER       25.0                  A Man Called Otto
# 194  DECEMBER        NaN                                NaN
#
#                                     Production company  \
# 0    Universal Pictures / Freckle Films / FilmNatio...
# 1                                          Saban Films
# 2                                          Saban Films
# 3            Paramount Pictures / Spyglass Media Group
# 4    Amazon Studios / Columbia Pictures / Sony Pict...
# ..                                                 ...
# 190          Universal Pictures / DreamWorks Animation
# 191               TriStar Pictures / Black Label Media
# 192                                 Paramount Pictures
# 193          Columbia Pictures / Playtone / SF Studios
# 194                                                NaN
#
#                                          Cast and crew   Ref.
# 0    Simon Kinberg (director/screenplay); Theresa R...    NaN
# 1    Patricia Harris Seeley (director/screenplay); ...    NaN
# 2    Asif Akbar (director); Koji Steven Sakai (scre...    NaN
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...    NaN
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...    NaN
# ..                                                 ...    ...
# 190  Joel Crawford (director); Antonio Banderas, Sa...  [162]
# 191  Kasi Lemmons (director); Anthony McCarten (scr...   [53]
# 192  Damien Chazelle (director/screenplay); Brad Pi...  [163]
# 193  Marc Forster (director), David Magee (screenpl...   [53]
# 194                                                NaN    NaN
#
# [195 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                                  Title  \
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 190       Puss in Boots: The Last Wish
# 191        I Wanna Dance with Somebody
# 192                            Babylon
# 193                  A Man Called Otto
# 194                                NaN
#
#                                          Cast and crew
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 190  Joel Crawford (director); Antonio Banderas, Sa...
# 191  Kasi Lemmons (director); Anthony McCarten (scr...
# 192  Damien Chazelle (director/screenplay); Brad Pi...
# 193  Marc Forster (director), David Magee (screenpl...
# 194                                                NaN
#
# [195 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'd0ee04e516fc923e0faa3878404593b6'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
        return np.NaN
    else:
        movie_id = result[0].id
        response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
        data_json = response.json()
        if data_json['genres']:
            genre_str = ' '
            for i in range(0, len(data_json['genres'])):
                genres.append(data_json['genres'][i]['name'])
            return genre_str.join(genres)
        else:
            return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].apply(lambda x: get_genre(str(x)))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15296\3769904103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].apply(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                                  Title  \
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 190       Puss in Boots: The Last Wish
# 191        I Wanna Dance with Somebody
# 192                            Babylon
# 193                  A Man Called Otto
# 194                                NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 190  Joel Crawford (director); Antonio Banderas, Sa...
# 191  Kasi Lemmons (director); Anthony McCarten (scr...
# 192  Damien Chazelle (director/screenplay); Brad Pi...
# 193  Marc Forster (director), David Magee (screenpl...
# 194                                                NaN
#
#                                         genres
# 0                              Action Thriller
# 1                              Horror Thriller
# 2                        Action Crime Thriller
# 3                      Horror Mystery Thriller
# 4    Animation Family Fantasy Comedy Adventure
# ..                                         ...
# 190  Animation Adventure Comedy Family Fantasy
# 191                              Drama History
# 192  Action Adventure Science Fiction Thriller
# 193                               Drama Comedy
# 194                                     Comedy
#
# [195 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15296\3848435694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15296\3646981363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                                  Title  \
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 190       Puss in Boots: The Last Wish
# 191        I Wanna Dance with Somebody
# 192                            Babylon
# 193                  A Man Called Otto
# 194                                NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 190  Joel Crawford (director); Antonio Banderas, Sa...
# 191  Kasi Lemmons (director); Anthony McCarten (scr...
# 192  Damien Chazelle (director/screenplay); Brad Pi...
# 193  Marc Forster (director), David Magee (screenpl...
# 194                                                NaN
#
#                                         genres  \
# 0                              Action Thriller
# 1                              Horror Thriller
# 2                        Action Crime Thriller
# 3                      Horror Mystery Thriller
# 4    Animation Family Fantasy Comedy Adventure
# ..                                         ...
# 190  Animation Adventure Comedy Family Fantasy
# 191                              Drama History
# 192  Action Adventure Science Fiction Thriller
# 193                               Drama Comedy
# 194                                     Comedy
#
#                             director_name  \
# 0                           Simon Kinberg
# 1                  Patricia Harris Seeley
# 2                              Asif Akbar
# 3    Matt Bettinelli-Olpin, Tyler Gillett
# 4           Jennifer Kluska, Derek Drymon
# ..                                    ...
# 190                         Joel Crawford
# 191                          Kasi Lemmons
# 192                       Damien Chazelle
# 193                          Marc Forster
# 194                                   nan
#
#                                    actor_1_name         actor_2_name  \
# 0                              Jessica Chastain       Lupita Nyong'o
# 1                                 Autumn Reeser         Antonio Cupo
# 2                                 Mickey Rourke    Michael Jai White
# 3                               Melissa Barrera        Mason Gooding
# 4                                  Andy Samberg         Selena Gomez
# ..                                          ...                  ...
# 190  Joel Crawford (director); Antonio Banderas          Salma Hayek
# 191                                 Naomi Ackie       Ashton Sanders
# 192                                   Brad Pitt        Margot Robbie
# 193                                   Tom Hanks  Manuel Garcia-Rulfo
# 194                                         nan                  NaN
#
#        actor_3_name
# 0     Penélope Cruz
# 1       Danny Trejo
# 2               NaN
# 3      Jenna Ortega
# 4      Kathryn Hahn
# ..              ...
# 190  Harvey Guillén
# 191   Stanley Tucci
# 192   Tobey Maguire
# 193             NaN
# 194             NaN
#
# [195 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df20
# Out:
#                             director_name  \
# 0                           Simon Kinberg
# 1                  Patricia Harris Seeley
# 2                              Asif Akbar
# 3    Matt Bettinelli-Olpin, Tyler Gillett
# 4           Jennifer Kluska, Derek Drymon
# ..                                    ...
# 190                         Joel Crawford
# 191                          Kasi Lemmons
# 192                       Damien Chazelle
# 193                          Marc Forster
# 194                                   nan
#
#                                    actor_1_name         actor_2_name  \
# 0                              Jessica Chastain       Lupita Nyong'o
# 1                                 Autumn Reeser         Antonio Cupo
# 2                                 Mickey Rourke    Michael Jai White
# 3                               Melissa Barrera        Mason Gooding
# 4                                  Andy Samberg         Selena Gomez
# ..                                          ...                  ...
# 190  Joel Crawford (director); Antonio Banderas          Salma Hayek
# 191                                 Naomi Ackie       Ashton Sanders
# 192                                   Brad Pitt        Margot Robbie
# 193                                   Tom Hanks  Manuel Garcia-Rulfo
# 194                                         nan                  NaN
#
#        actor_3_name                                     genres  \
# 0     Penélope Cruz                            Action Thriller
# 1       Danny Trejo                            Horror Thriller
# 2               NaN                      Action Crime Thriller
# 3      Jenna Ortega                    Horror Mystery Thriller
# 4      Kathryn Hahn  Animation Family Fantasy Comedy Adventure
# ..              ...                                        ...
# 190  Harvey Guillén  Animation Adventure Comedy Family Fantasy
# 191   Stanley Tucci                              Drama History
# 192   Tobey Maguire  Action Adventure Science Fiction Thriller
# 193             NaN                               Drama Comedy
# 194             NaN                                     Comedy
#
#                            movie_title
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 190       Puss in Boots: The Last Wish
# 191        I Wanna Dance with Somebody
# 192                            Babylon
# 193                  A Man Called Otto
# 194                                NaN
#
# [195 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      6
# actor_3_name     20
# genres            1
# movie_title       2
# comb             20
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15296\2267385682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#                             director_name  \
# 0                           Simon Kinberg
# 1                  Patricia Harris Seeley
# 3    Matt Bettinelli-Olpin, Tyler Gillett
# 4           Jennifer Kluska, Derek Drymon
# 5                             Luis Prieto
# ..                                    ...
# 188                         James Cameron
# 189                     David F. Sandberg
# 190                         Joel Crawford
# 191                          Kasi Lemmons
# 192                       Damien Chazelle
#
#                                    actor_1_name    actor_2_name  \
# 0                              Jessica Chastain  Lupita Nyong'o
# 1                                 Autumn Reeser    Antonio Cupo
# 3                               Melissa Barrera   Mason Gooding
# 4                                  Andy Samberg    Selena Gomez
# 5                              Cameron Monaghan    Frank Grillo
# ..                                          ...             ...
# 188                             Sam Worthington     Zoe Saldana
# 189                                Zachary Levi     Asher Angel
# 190  Joel Crawford (director); Antonio Banderas     Salma Hayek
# 191                                 Naomi Ackie  Ashton Sanders
# 192                                   Brad Pitt   Margot Robbie
#
#           actor_3_name                                     genres  \
# 0        Penélope Cruz                            Action Thriller
# 1          Danny Trejo                            Horror Thriller
# 3         Jenna Ortega                    Horror Mystery Thriller
# 4         Kathryn Hahn  Animation Family Fantasy Comedy Adventure
# 5           Lilly Krug                                   Thriller
# ..                 ...                                        ...
# 188       Stephen Lang   Action Adventure Fantasy Science Fiction
# 189  Jack Dylan Grazer                      Comedy Action Fantasy
# 190     Harvey Guillén  Animation Adventure Comedy Family Fantasy
# 191      Stanley Tucci                              Drama History
# 192      Tobey Maguire  Action Adventure Science Fiction Thriller
#
#                            movie_title  \
# 0                              the 355
# 1             the legend of la llorona
# 3                               scream
# 4    hotel transylvania: transformania
# 5                            shattered
# ..                                 ...
# 188           avatar: the way of water
# 189           shazam! fury of the gods
# 190       puss in boots: the last wish
# 191        i wanna dance with somebody
# 192                            babylon
#
#                                                   comb
# 0    Jessica Chastain Lupita Nyong'o Penélope Cruz ...
# 1    Autumn Reeser Antonio Cupo Danny Trejo Patrici...
# 3    Melissa Barrera Mason Gooding Jenna Ortega Mat...
# 4    Andy Samberg Selena Gomez Kathryn Hahn Jennife...
# 5    Cameron Monaghan Frank Grillo Lilly Krug Luis ...
# ..                                                 ...
# 188  Sam Worthington Zoe Saldana Stephen Lang James...
# 189  Zachary Levi Asher Angel Jack Dylan Grazer Dav...
# 190  Joel Crawford (director); Antonio Banderas Sal...
# 191  Naomi Ackie Ashton Sanders Stanley Tucci Kasi ...
# 192  Brad Pitt Margot Robbie Tobey Maguire Damien C...
#
# [175 rows x 7 columns]

# %%
old_df = pd.read_csv('final1_data2.csv')

# %%
final_df = old_df.append(new_df20,ignore_index=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15296\3205022339.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df.shape
# Out:
# (6631, 7)
